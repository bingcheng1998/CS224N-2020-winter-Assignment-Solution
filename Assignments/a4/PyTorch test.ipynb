# %%
import torch.nn as nn
import torch

# %%
embedding = nn.Embedding(10, 3, padding_idx=4)

# %%
input = torch.LongTensor([[1,2,4,5],[4,3,2,9]])

# %%
embedding(input)
# Out:
# tensor([[[-2.0800,  0.6906, -0.2968],
#          [-0.7027,  0.0254, -0.6911],
#          [ 0.0000,  0.0000,  0.0000],
#          [-0.1136,  0.2720, -0.9874]],
#
#         [[ 0.0000,  0.0000,  0.0000],
#          [-0.5625,  2.8111,  0.5150],
#          [-0.7027,  0.0254, -0.6911],
#          [-0.5959,  0.6750,  0.8034]]], grad_fn=<EmbeddingBackward>)

# %%
from utils import pad_sents

# %%
sents = [
    ['I', 'like', 'apple'],
    ['he', 'is', 'beautiful','but','smelling'],
    ['hi']
]
pad_token = '<pad>'
pad_sents(sents, pad_token)
# Out:
# [['I', 'like', 'apple', '<pad>', '<pad>'],
#  ['he', 'is', 'beautiful', 'but', 'smelling'],
#  ['hi', '<pad>', '<pad>', '<pad>', '<pad>']]
