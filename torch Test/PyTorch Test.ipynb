# %%
import torch
import torch.nn as nn

# %%
m = nn.Conv1d(16, 33, kernel_size=4, stride=2, padding  = 2)
input = torch.randn(20, 16, 50)
output = m(input)

output.size()
# Out:
# torch.Size([20, 33, 26])

# %% [markdown]
# Here 50 -(KERNEL = 3, STRIDE = 2)-> 24
#
# because W2 = (W - F + 2P)/S +1 = (50 - 3 + 0 * 2)/2 + 1 =

# %%
si=torch.randn(4,5,2)
si
# Out:
# tensor([[[-0.5259, -0.2787],
#          [ 0.3290,  1.2157],
#          [ 1.4758,  0.4995],
#          [-0.7637, -0.8811],
#          [-0.8599, -0.5201]],
#
#         [[ 1.5784,  0.0107],
#          [ 0.0236, -0.6687],
#          [-0.6696, -0.7687],
#          [-2.8563,  0.4249],
#          [-1.4614, -1.1893]],
#
#         [[-0.8123,  0.2724],
#          [-0.6748,  0.6148],
#          [-0.8653,  1.0803],
#          [-0.4278,  0.4054],
#          [ 1.6177, -1.8250]],
#
#         [[ 1.8049,  0.8921],
#          [ 1.2586,  0.1651],
#          [-0.4370,  1.1177],
#          [-0.5240, -0.6739],
#          [-1.4329,  0.0144]]])

# %%
torch.max(si, 2)[0]
# Out:
# tensor([[-0.2787,  1.2157,  1.4758, -0.7637, -0.5201],
#         [ 1.5784,  0.0236, -0.6696,  0.4249, -1.1893],
#         [ 0.2724,  0.6148,  1.0803,  0.4054,  1.6177],
#         [ 1.8049,  1.2586,  1.1177, -0.5240,  0.0144]])
